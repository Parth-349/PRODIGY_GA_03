# %% [markdown]
# <a href="https://colab.research.google.com/github/Parth-349/PRODIGY_GA_03/blob/main/Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Step 1: Build the Markov Chain
def build_markov_chain(text, n=1):
    words = text.split()
    markov_chain = {}

    for i in range(len(words) - n):
        key = tuple(words[i:i + n])
        next_word = words[i + n]
        if key not in markov_chain:
            markov_chain[key] = []
        markov_chain[key].append(next_word)

    return markov_chain

# Step 2: Generate Text from the Chain
    random.seed(42)
def generate_text(chain, length=50, n=1):
    start = random.choice(list(chain.keys()))
    result = list(start)

    for _ in range(length - n):
        key = tuple(result[-n:])
        if key in chain:
            next_word = random.choice(chain[key])
            result.append(next_word)
        else:
            break

    return ' '.join(result)

# Step 3: Input text
sample_text = """
The quick brown fox jumps over the lazy dog.
The quick brown fox is fast and clever.
The lazy dog lies down and watches.
"""

# Step 4: Build and Generate
n = 1
chain = build_markov_chain(sample_text, n=n)
generated_text = generate_text(chain, length=30, n=n)

# Step 5: Output
print("📄 Generated Text:\n")
print(generated_text)
# Out:
# 📄 Generated Text:
#
# dog. The lazy dog lies down and clever. The lazy dog. The lazy dog. The quick brown fox jumps over the lazy dog. The quick brown fox jumps over the
